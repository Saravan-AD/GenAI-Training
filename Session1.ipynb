# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("telecom_dataset-.csv")

# %%
data.head()
# Out:
#    customer_id  tenure_months  monthly_data_usage_gb  monthly_call_minutes  \
# 0            1             39                  14.69                 409.0
# 1            2             52                  18.67                 481.0
# 2            3             29                  14.09                 102.0
# 3            4             15                  16.32                 596.0
# 4            5             43                  16.69                 594.0
#
#    support_calls contract_type  churn
# 0              0       Prepaid      0
# 1              1       Prepaid      0
# 2              2       Prepaid      0
# 3              1      Postpaid      1
# 4              0      Postpaid      0

# %%
data.head(10)
# Out:
#    customer_id  tenure_months  monthly_data_usage_gb  monthly_call_minutes  \
# 0            1             39                  14.69                 409.0
# 1            2             52                  18.67                 481.0
# 2            3             29                  14.09                 102.0
# 3            4             15                  16.32                 596.0
# 4            5             43                  16.69                 594.0
# 5            6              8                  10.88                 336.0
# 6            7             21                  15.63                 806.0
# 7            8             39                   7.30                 584.0
# 8            9             58                  13.75                 576.0
# 9           10             19                  14.89                 578.0
#
#    support_calls contract_type  churn
# 0              0       Prepaid      0
# 1              1       Prepaid      0
# ...

# %%
data.tail(10)
# Out:
#       customer_id  tenure_months  monthly_data_usage_gb  monthly_call_minutes  \
# 5990         5991             13                  14.42                 518.0
# 5991         5992              5                   8.25                 687.0
# 5992         5993             26                  16.60                 290.0
# 5993         5994             49                  18.14                 536.0
# 5994         5995              3                  10.70                 103.0
# 5995         5996              7                   6.84                 399.0
# 5996         5997             58                  12.50                 411.0
# 5997         5998             49                  22.80                 522.0
# 5998         5999             39                   6.71                 322.0
# 5999         6000             53                   9.37                 437.0
#
#       support_calls contract_type  churn
# 5990              3       Prepaid      0
# ...

# %%
data.columns
# Out:
# Index(['customer_id', 'tenure_months', 'monthly_data_usage_gb',
#        'monthly_call_minutes', 'support_calls', 'contract_type', 'churn'],
#       dtype='object')

# %%
data.describe() #will display the statistical values associated with the numerical columns
# Out:
#        customer_id  tenure_months  monthly_data_usage_gb  \
# count  6000.000000    6000.000000            6000.000000
# mean   3000.500000      30.226000              12.017943
# std    1732.195139      16.992588               4.924738
# min       1.000000       1.000000               1.000000
# 25%    1500.750000      16.000000               8.620000
# 50%    3000.500000      30.000000              12.020000
# 75%    4500.250000      45.000000              15.420000
# max    6000.000000      59.000000              32.260000
#
#        monthly_call_minutes  support_calls        churn
# count           6000.000000    6000.000000  6000.000000
# mean             400.402333       1.526667     0.290333
# std              148.935061       1.223603     0.453954
# min               50.000000       0.000000     0.000000
# 25%              298.000000       1.000000     0.000000
# 50%              399.000000       1.000000     0.000000
# 75%              502.000000       2.000000     1.000000
# ...

# %%
#checking for missing values in the dataset
data.isnull().sum() # for each column we get a sum of how may null values are present
# Out:
# customer_id              0
# tenure_months            0
# monthly_data_usage_gb    0
# monthly_call_minutes     0
# support_calls            0
# contract_type            0
# churn                    0
# dtype: int64

# %%
avg_data=data['monthly_data_usage_gb'].mean()

# %%
print(avg_data)
# Out:
# 12.017943333333333

# %%
churned_percent=data['churn'].mean()

# %%
print(churned_percent)
print(data['churn'])
# Out:
# 0.29033333333333333
# 0       0
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 5995    0
# 5996    0
# 5997    0
# 5998    0
# 5999    0
# Name: churn, Length: 6000, dtype: int64

# %%
data['churn'].unique()
# Out:
# array([0, 1])

# %%
data['churn'].value_counts()
# Out:
# churn
# 0    4258
# 1    1742
# Name: count, dtype: int64

# %%
data['contract_type'].value_counts()
# Out:
# contract_type
# Postpaid    3566
# Prepaid     2434
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,5))
sns.histplot(data['monthly_data_usage_gb'],bins=30)#bins will manage the thickness of histogram
plt.title("Distribution of monthly data usage")
plt.xlabel("GB")
plt.ylabel("Number of customers")
# Out:
# Text(0, 0.5, 'Number of customers')

# %%
data['monthly_data_usage_gb']
# Out:
# 0       14.69
# 1       18.67
# 2       14.09
# 3       16.32
# 4       16.69
#         ...
# 5995     6.84
# 5996    12.50
# 5997    22.80
# 5998     6.71
# 5999     9.37
# Name: monthly_data_usage_gb, Length: 6000, dtype: float64

# %%
plt.figure(figsize=(5,5))
sns.histplot(data['monthly_call_minutes'])
# Out:
# <Axes: xlabel='monthly_call_minutes', ylabel='Count'>

# %%
plt.figure(figsize=(5,5))
sns.histplot(data['monthly_data_usage_gb'],kde=True)#bins will manage the thickness of histogram
plt.title("Distribution of monthly data usage")
plt.xlabel("GB")
plt.ylabel("Number of customers")
# Out:
# Text(0, 0.5, 'Number of customers')

# %%
data2=pd.read_csv('finance_dataset.csv')

# %%
data2
# Out:
#       customer_id  age  annual_income  credit_score  loan_amount  \
# 0               1   49       29605.62         769.0     17194.35
# 1               2   31       15000.00         593.0      4748.19
# 2               3   58       49802.16         611.0     18636.45
# 3               4   35       69843.04         825.0     22438.00
# 4               5   52       56757.43         780.0     36931.71
# ...           ...  ...            ...           ...          ...
# 5995         5996   38      105766.41         717.0     59045.21
# 5996         5997   41       90390.98         719.0     41831.62
# 5997         5998   31       73676.53         675.0     20557.63
# 5998         5999   50       21140.88         646.0     16244.79
# 5999         6000   39       69642.68         773.0     43444.40
#
#       existing_loans  loan_default
# 0                  2             1
# 1                  1             0
# 2                  0             1
# 3                  1             0
# ...

# %%
data2.columns
# Out:
# Index(['customer_id', 'age', 'annual_income', 'credit_score', 'loan_amount',
#        'existing_loans', 'loan_default'],
#       dtype='object')

# %%
data2['loan_amount'].max()
# Out:
# 97503.02

# %%
data2['annual_income'].median()
# Out:
# 60571.395000000004

# %%
data2['loan_default'].value_counts()
# Out:
# loan_default
# 0    3717
# 1    2283
# Name: count, dtype: int64

# %%
plt.figure(figsize=(5,5))
sns.histplot(data2['annual_income'],bins=30)#bins will manage the thickness of histogram
plt.title("Distribution of income")
plt.xlabel("Anuual income")
plt.ylabel("Number of customers")
# Out:
# Text(0, 0.5, 'Number of customers')

# %%
#Relationship betwee ncredit score and loan amount
plt.figure(figsize=(5,5))
sns.scatterplot(
    x=data2['credit_score'],
    y=data2['loan_amount']
)
plt.title("Credit score vs loan amount")
plt.xlabel("credit score")
plt.ylabel("loan amount")
# Out:
# Text(0, 0.5, 'loan amount')
